# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

df = pd.read_csv("BankNote_Authentication.csv")
df.head()
# Out:
#    variance  skewness  curtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %%
df.shape
# Out:
# (1372, 5)

# %%
df.isnull().sum()
# Out:
# variance    0
# skewness    0
# curtosis    0
# entropy     0
# class       0
# dtype: int64

# %%
ax = df.hist(figsize=(20,10))
ax
# Out:
# array([[<Axes: title={'center': 'variance'}>,
#         <Axes: title={'center': 'skewness'}>],
#        [<Axes: title={'center': 'curtosis'}>,
#         <Axes: title={'center': 'entropy'}>],
#        [<Axes: title={'center': 'class'}>, <Axes: >]], dtype=object)

# %%
df['class'].value_counts()
# Out:
# 0    762
# 1    610
# Name: class, dtype: int64

# %%
df.describe()
# Out:
#           variance     skewness     curtosis      entropy        class
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean      0.433735     1.922353     1.397627    -1.191657     0.444606
# std       2.842763     5.869047     4.310030     2.101013     0.497103
# min      -7.042100   -13.773100    -5.286100    -8.548200     0.000000
# 25%      -1.773000    -1.708200    -1.574975    -2.413450     0.000000
# 50%       0.496180     2.319650     0.616630    -0.586650     0.000000
# 75%       2.821475     6.814625     3.179250     0.394810     1.000000
# max       6.824800    12.951600    17.927400     2.449500     1.000000

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True,cmap='mako',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(12,6)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 import seaborn as sns
#       2 sns.heatmap(df.corr(),annot=True,cmap='mako',linewidths=0.2)
# ----> 3 fig=plt.gcf()
#       4 fig.set_size_inches(12,6)
#       5 plt.show()
#
# File C:\Anaconda\lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'gcf'

# %%
sns.pairplot(df, hue='class', palette={0:'green', 1:'red'}, plot_kws={"s":3})
